# %% [markdown]
# ## Introducción a Jupyter Notebooks
# ___

# %% [markdown]
# ## Cómo usar esta Guía
#
# La página web en la que te encuentras es en realidad una aplicación llamada Jupyter Notebook. Una celda de *entrada/input* parece un cuadro gris claro con un `In [ ] ` a su izquierda. Cada una de las celdas de entrada contiene códigos: instrucciones para hacer que el computador haga algo.
#
# Para activar o seleccionar una celda, haz clic en cualquier lugar dentro de ella.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona la celda de abajo y lee su contenido.</b></font>
# </div>

# %% [markdown]
# # Tabla de Contenidos
#
# * [Cómo usar esta Guía](#How-to-Use-This-Notebook)
# * [Configuración Previa a la Actividad](#Pre-Activity-Setup)
# ___

# %%
# El texto que sigue a un "#" es un comentario.
# Los comentarios no afectan su código de ninguna manera.
# Lea siempre los comentarios en la parte superior de cada celda con la que interactúe.
# Los comentarios se utilizarán para describir lo que realmente está haciendo el código de la celda.

# %% [markdown]
# Para ejecutar una celda seleccionada, haz clic en el pequeño botón de reproducción o presiona `[Shift + Enter]` en tu teclado.
#
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona la celda de abajo y lee su contenido. Luego, ejecuta la celda.</b></font>
#         <br> Si aparece una advertencia, simplemente haz clic en <em>"Ejecutar de todos modos"</em>, este código es seguro 😉
#         <br> Además, si deseas guardar tu progreso, haz clic en el botón <em>"Guardar una copia en Drive"</em> en la parte superior.
#       </div>

# %%
# El texto que NO está antecedido por un "#" se considera código.
# Las líneas de código son instrucciones dadas a tu computador.
# La línea de código de abajo es una instrucción de "impresión" (print), que literalmente imprime el texto entre comillas.

print("¡Felicitaciones! ¡Has ejecutado con éxito tu primera celda!")
# Out:
# ¡Felicitaciones! ¡Has ejecutado con éxito tu primera celda!

# %% [markdown]
# Ejecutar una celda crea una *salida/output* directamente debajo de ella. Una salida puede ser un texto, un gráfico, un control deslizante interactivo, ¡o incluso nada en absoluto! Cuando has ejecutado una celda, aparece un número entre corchetes, por ejemplo [1] al lado izquierdo de la celda.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Abre todas las secciones de este bloc de notas seleccionando el menú "Ver" y "Expandir secciones" </b></font>
#         <br>
# </div>
#
#
# Puedes obtener más información sobre cómo funcionan los Jupyter Notebooks en https://try.jupyter.org/ (página en inglés)
# ___

# %% [markdown]
# # Configuración Previa a la Actividad
#
# Para que cualquiera de las actividades funcione correctamente, debes importar las librerias necesarias para el funcionamiento del código de esta guía. Estos ya deberían haberse cargado cuando ejecutaste todas las celdas.
#
# <div class='alert alert-info'>
#     <font size='3'><b>Selecciona y ejecuta la celda a continuación.</b></font>
# </div>

# %%
# Clonar el repositorio de GitHub e importar los módulos necesarios usando requisitos.txt.

# !git clone https://github.com/mas-astro/inspirastem-ppd-CO
# Out:
# fatal: destination path 'inspirastem-ppd-CO' already exists and is not an empty directory.
# /content
# inspirastem-ppd-CO  sample_data

# %% [markdown]
# Este comando te indica la ruta del archivo de tu ubicación actual. En este caso, debería ser `content/`.

# %%
# !pwd

# %% [markdown]
# El siguiente comando te muestra el contenido del directorio en el que te encuentras actualmente. Debería contener el repositorio de GitHub que acabamos de clonar: `inspirastem-ppd-CO`.

# %%
# !ls

# %%
# cambiamos directorio con %cd
# %cd /content/inspirastem-ppd-CO
# Out:
# /content/inspirastem-ppd-CO

# %% [markdown]
# Ahora, importaremos las librerias y los paquetes necesarios para nuestras actividades y ejercicios.

# %%
# AVISO: Al ejecutar esta celda, es posible que aparezca
# un mensaje pidiéndote que reinicies la sesión. Esto es
# normal y podrás volver a ejecutar las celdas.

# !pip install -r 00_antecurso/requisitos.txt
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
#%config InlineBackend.figure_format = 'retina'
from matplotlib import cm
from ipywidgets import *
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore")

print('¡Listo! Has importado correctamente las bibliotecas.')
# Out:
# 00_antecurso  01_intro	02_analises  03_resultados  data  README.md
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 2)) (2.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 3)) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 4)) (1.16.3)
# Requirement already satisfied: astropy in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 5)) (7.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 6)) (3.10.0)
# Requirement already satisfied: specutils in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 7)) (2.4.0)
# Requirement already satisfied: statistics in /usr/local/lib/python3.13/dist-packages (from -r 00_antecurso/requisitos.txt (line 8)) (1.0.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->-r 00_antecurso/requisitos.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->-r 00_antecurso/requisitos.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->-r 00_antecurso/requisitos.txt (line 3)) (2026.3)
# Requirement already satisfied: astropy-iers-data>=0.2026.6.22.1.23.34 in /usr/local/lib/python3.13/dist-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (0.2026.8.24.0.24.29)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.13/dist-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (26.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.13/dist-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (2.0.1.5)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.13/dist-packages (from astropy->-r 00_antecurso/requisitos.txt (line 5)) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r 00_antecurso/requisitos.txt (line 6)) (3.3.2)
# Requirement already satisfied: gwcs>=0.25.1 in /usr/local/lib/python3.13/dist-packages (from specutils->-r 00_antecurso/requisitos.txt (line 7)) (1.0.3)
# Requirement already satisfied: asdf-astropy>=0.8 in /usr/local/lib/python3.13/dist-packages (from specutils->-r 00_antecurso/requisitos.txt (line 7)) (0.11.0)
# Requirement already satisfied: asdf>=3.3.0 in /usr/local/lib/python3.13/dist-packages (from specutils->-r 00_antecurso/requisitos.txt (line 7)) (5.4.0)
# Requirement already satisfied: ndcube>=2.0 in /usr/local/lib/python3.13/dist-packages (from specutils->-r 00_antecurso/requisitos.txt (line 7)) (2.4.1)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.13/dist-packages (from statistics->-r 00_antecurso/requisitos.txt (line 8)) (0.21.2)
# Requirement already satisfied: asdf-standard>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 7)) (1.5.0)
# Requirement already satisfied: jmespath>=0.6.2 in /usr/local/lib/python3.13/dist-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 7)) (1.1.0)
# Requirement already satisfied: semantic_version>=2.8 in /usr/local/lib/python3.13/dist-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 7)) (2.10.0)
# Requirement already satisfied: typing-extensions>=4.16 in /usr/local/lib/python3.13/dist-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 7)) (4.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from asdf>=3.3.0->specutils->-r 00_antecurso/requisitos.txt (line 7)) (26.1.0)
# Requirement already satisfied: asdf-coordinates-schemas>=0.4 in /usr/local/lib/python3.13/dist-packages (from asdf-astropy>=0.8->specutils->-r 00_antecurso/requisitos.txt (line 7)) (0.5.1)
# Requirement already satisfied: asdf-transform-schemas>=0.6 in /usr/local/lib/python3.13/dist-packages (from asdf-astropy>=0.8->specutils->-r 00_antecurso/requisitos.txt (line 7)) (0.6.0)
# Requirement already satisfied: asdf_wcs_schemas>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from gwcs>=0.25.1->specutils->-r 00_antecurso/requisitos.txt (line 7)) (0.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->-r 00_antecurso/requisitos.txt (line 3)) (1.17.0)
# ¡Listo! Has importado correctamente las bibliotecas.

# %% [markdown]
# ### Nota al margen de programación
#
# Las celdas anteriores son una forma de importar las funciones necesarias y otras cosas que nos permiten hacer dibujos y operaciones matemáticas con mucha facilidad. En la siguiente celda, usaremos un diccionario para agrupar cosas fácilmente. Así como en un diccionario normal hay una palabra y una definición, este diccionario actúa de manera similar pero en lugar de una palabra, lo llamamos clave y en lugar de una definición lo llamamos valor.
#
#
# ```python
# dictionary = {key1 : value1, key2 : value2 ...}
# ```

# %%
#Defina algunas preferencias de visualización de imágenes en un "objeto de diccionario", para usar durante la actividad:
myargs = {'interpolation': 'nearest', 'origin': 'lower', 'cmap': cm.nipy_spectral}
# La siguiente línea de comando especifica un mapa de color alternativo, que algunos pueden encontrar más cómodo para trabajar.
# Descomente y ejecute la siguiente línea si desea usarla:
#myargs = {'interpolation': 'nearest', 'origin': 'lower', 'cmap': cm.hot}

# %% [markdown]
# ___
